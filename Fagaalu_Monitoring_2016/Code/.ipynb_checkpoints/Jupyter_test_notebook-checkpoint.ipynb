# %% [markdown]
# # This notebook shows how to run code in a Github repository
# % All the code is here
# % All the data is here
# % and it will explain step by step how its doing things

# %% [markdown]
# So here we import all the modules

# %%
# %matplotlib notebook

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# generate some data

# %%
t = np.arange(0., 5., 0.2)

# %%
plt.plot(t,t,ls='-',c='k')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Let's try running a module and get the output

# %%
import test

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %% R
# print('x')
# Out:
# ERROR: Cell magic `%%` not found.

# %%
## Try an R command
# %R print('x')
# Out:
# array(['x'],
#       dtype='|S1')

# %%
% lsmagic

# see if %%R is there

# %%
#import rpy2.interactive.packages

# %%
## Import R package
#r.packages.importr("EcoHydRology")
# Out:
# rpy2.robjects.packages.Package as a <module 'EcoHydRology' (built-in)>

# %%
# Out:
# array(['x'],
#       dtype='|S1')
